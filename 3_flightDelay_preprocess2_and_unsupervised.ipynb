# %%
import pandas as pd

df = pd.read_csv(r'G:\Other computers\My Laptop D14\Belgeler\CODING\Python.PROJECTS\MTM-DataMining-FlightDelay\manipulated_data\flightDelay_manipulated.csv')

# %%
df.select_dtypes(object).head()
# Out:
#   DepTimeBlk Merged by Marketing_Airline_Network Merged by Operating_Airline  \
# 0  1600-1659       DL / DL / 19790 / DL / N545US             DL / 19790 / DL
# 1  1000-1059       DL / DL / 19790 / DL / N345NB             DL / 19790 / DL
# 2  1100-1159       DL / DL / 19790 / DL / N978AT             DL / 19790 / DL
# 3  1200-1259       DL / DL / 19790 / DL / N978AT             DL / 19790 / DL
# 4  0900-0959       DL / DL / 19790 / DL / N878DN             DL / 19790 / DL
#
#                            Merged by OriginAirportID  \
# 0  10397 / 1039707 / 30397 / ATL / Atlanta, GA / ...
# 1  11697 / 1169706 / 32467 / FLL / Fort Lauderdal...
# 2  10397 / 1039707 / 30397 / ATL / Atlanta, GA / ...
# 3  12448 / 1244807 / 32448 / JAN / Jackson/Vicksb...
# 4  14524 / 1452401 / 34524 / RIC / Richmond, VA /...
#
#                           Merged by DestAirportSeqID       Merged by DepDelay  \
# 0  1169706 / 11697 / 32467 / FLL / Fort Lauderdal...  -4.0 / 0.0 / 0.0 / -1.0
# 1  1449202 / 14492 / 34492 / RDU / Raleigh/Durham...  -5.0 / 0.0 / 0.0 / -1.0
# 2  1244807 / 12448 / 32448 / JAN / Jackson/Vicksb...  -4.0 / 0.0 / 0.0 / -1.0
# 3  1039707 / 10397 / 30397 / ATL / Atlanta, GA / ...  -7.0 / 0.0 / 0.0 / -1.0
# 4  1039707 / 10397 / 30397 / ATL / Atlanta, GA / ...  -3.0 / 0.0 / 0.0 / -1.0
#
#   Merged by CRSArrTime        Merged by ArrDelay Merged by Distance  \
# 0     1821 / 1800-1859   -1.0 / 0.0 / 0.0 / -1.0          581.0 / 3
# 1     1227 / 1200-1259  -15.0 / 0.0 / 0.0 / -1.0          680.0 / 3
# 2     1142 / 1100-1159  -11.0 / 0.0 / 0.0 / -1.0          341.0 / 2
# 3     1458 / 1400-1459  -23.0 / 0.0 / 0.0 / -2.0          341.0 / 2
# 4     1050 / 1000-1059  -12.0 / 0.0 / 0.0 / -1.0          481.0 / 2
#
#        DelayLabel
# 0  Almost on time
# 1  Almost on time
# 2  Almost on time
# 3           Early
# 4  Almost on time

# %%
df.select_dtypes(object).nunique()
# Out:
# DepTimeBlk                               13
# Merged by Marketing_Airline_Network    3996
# Merged by Operating_Airline              14
# Merged by OriginAirportID               318
# Merged by DestAirportSeqID              317
# Merged by DepDelay                      739
# Merged by CRSArrTime                    660
# Merged by ArrDelay                      786
# Merged by Distance                     1296
# DelayLabel                                3
# dtype: int64

# %% [markdown]
# Veri setinde one-hot encoding yapılması durumunda curse of dimensionality (boyut laneti) ile karşılaşılması olasıdır. Bunun önüne geçebilmek adına bir çözüm geliştirilmelidir.

# %% [markdown]
# Öncelikle sadece sayısal verileri üzerinden kümeleme yapalım.

# %%
numeric_atts = df.select_dtypes(include=[float, int])
numeric_atts = numeric_atts.iloc[:,:-4]
numeric_atts.head()
# Out:
#    Flight_Number_Marketing_Airline  CRSDepTime  DepTime  TaxiOut  TaxiIn  \
# 0                             1582        1631   1627.0     15.0     5.0
# 1                             1583        1024   1019.0     17.0     3.0
# 2                             1584        1117   1113.0     14.0     4.0
# 3                             1584        1237   1230.0     11.0     5.0
# 4                             1585         900    857.0     13.0     8.0
#
#    ArrTime  Cancelled  Diverted  CRSElapsedTime  ActualElapsedTime  AirTime  \
# 0   1820.0        0.0       0.0           110.0              113.0     93.0
# 1   1212.0        0.0       0.0           123.0              113.0     93.0
# 2   1131.0        0.0       0.0            85.0               78.0     60.0
# 3   1435.0        0.0       0.0            81.0               65.0     49.0
# 4   1038.0        0.0       0.0           110.0              101.0     80.0
#
#    Flights  DivAirportLandings
# 0      1.0                   0
# 1      1.0                   0
# 2      1.0                   0
# 3      1.0                   0
# 4      1.0                   0

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

scaler = StandardScaler()
columns_ = numeric_atts.columns
numeric_atts_scaled = scaler.fit_transform(numeric_atts) #etiketli veriler çıkartıldı

# %%
numeric_atts_df_scaled = pd.DataFrame(numeric_atts_scaled, columns = numeric_atts.columns)

# %%
numeric_atts_df_scaled
# Out:
#         Flight_Number_Marketing_Airline  CRSDepTime   DepTime   TaxiOut  \
# 0                             -0.817258    1.278581  1.190874 -0.241404
# 1                             -0.816695   -0.567731 -0.602018 -0.046715
# 2                             -0.816133   -0.284853 -0.324827 -0.338748
# 3                             -0.816133    0.080151  0.020187 -0.630781
# 4                             -0.815570   -0.944901 -1.079729 -0.436092
# ...                                 ...         ...       ...       ...
# 291527                         1.666006    1.248164 -0.032892  1.413449
# 291528                         1.666006    1.248164  1.184977 -0.728125
# 291529                         1.666006    1.248164  1.529990 -0.436092
# 291530                         1.666568    1.610126  1.518195  0.634695
# 291531                         1.666568    1.610126  1.833720  0.050629
#
#           TaxiIn   ArrTime  Cancelled  Diverted  CRSElapsedTime  \
# 0      -0.416642  1.185754        0.0       0.0       -0.417425
# 1      -0.702176 -0.682987        0.0       0.0       -0.209648
# 2      -0.559409 -0.931948        0.0       0.0       -0.816996
# 3      -0.416642  0.002423        0.0       0.0       -0.880928
# 4       0.011658 -1.217791        0.0       0.0       -0.417425
# ...          ...       ...        ...       ...             ...
# 291527  5.151264  0.211427        0.0       0.0        0.237872
# 291528  1.153793  1.213416        0.0       0.0        0.237872
# 291529  3.295295  1.751294        0.0       0.0        0.237872
# 291530 -0.702176  1.468524        0.0       0.0       -0.657168
# 291531 -0.273876  1.800471        0.0       0.0       -0.657168
#
#         ActualElapsedTime   AirTime  Flights  DivAirportLandings
# 0               -0.250867 -0.167621      0.0           -0.001852
# 1               -0.250867 -0.167621      0.0           -0.001852
# 2               -0.815845 -0.712981      0.0           -0.001852
# 3               -1.025694 -0.894768      0.0           -0.001852
# 4               -0.444574 -0.382460      0.0           -0.001852
# ...                   ...       ...      ...                 ...
# 291527           0.685382 -0.134569      0.0           -0.001852
# 291528          -0.073303 -0.084990      0.0           -0.001852
# 291529           0.217257 -0.084990      0.0           -0.001852
# 291530          -0.557569 -0.597298      0.0           -0.001852
# 291531          -0.541427 -0.531194      0.0           -0.001852
#
# [291532 rows x 13 columns]

# %%
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans

kmeans = KMeans()
visualizer = KElbowVisualizer(kmeans, k=(1,10))

# %%
visualizer.fit(numeric_atts_scaled)
visualizer.poof()
# Out:
# c:\Users\Anıl\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Anıl\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Anıl\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Anıl\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Anıl\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Anıl\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Anıl\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Anıl\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\Anıl\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# Bir şey ifade etmiyor

# %% [markdown]
# One-Hot Encoding yapalım ve tüm veriler ile kümeleme yapmayı deneylim.

# %%
df_ohe = pd.get_dummies(df.select_dtypes(include=[object]).iloc[:, :-1], prefix='Encoded')

# %%
df_ohe
# Out:
#         Encoded_0600-0659  Encoded_0700-0759  Encoded_0800-0859  \
# 0                   False              False              False
# 1                   False              False              False
# 2                   False              False              False
# 3                   False              False              False
# 4                   False              False              False
# ...                   ...                ...                ...
# 291527              False              False              False
# 291528              False              False              False
# 291529              False              False              False
# 291530              False              False              False
# 291531              False              False              False
#
#         Encoded_0900-0959  Encoded_1000-1059  Encoded_1100-1159  \
# 0                   False              False              False
# 1                   False               True              False
# 2                   False              False               True
# 3                   False              False              False
# 4                    True              False              False
# ...                   ...                ...                ...
# 291527              False              False              False
# 291528              False              False              False
# 291529              False              False              False
# 291530              False              False              False
# 291531              False              False              False
#
#         Encoded_1200-1259  Encoded_1300-1359  Encoded_1400-1459  \
# 0                   False              False              False
# 1                   False              False              False
# 2                   False              False              False
# 3                    True              False              False
# 4                   False              False              False
# ...                   ...                ...                ...
# 291527              False              False              False
# 291528              False              False              False
# 291529              False              False              False
# 291530              False              False              False
# 291531              False              False              False
#
#         Encoded_1500-1559  ...  Encoded_99.0 / 1  Encoded_990.0 / 4  \
# 0                   False  ...             False              False
# 1                   False  ...             False              False
# 2                   False  ...             False              False
# 3                   False  ...             False              False
# 4                   False  ...             False              False
# ...                   ...  ...               ...                ...
# 291527              False  ...             False              False
# 291528              False  ...             False              False
# 291529              False  ...             False              False
# 291530              False  ...             False              False
# 291531              False  ...             False              False
#
#         Encoded_991.0 / 4  Encoded_992.0 / 4  Encoded_993.0 / 4  \
# 0                   False              False              False
# 1                   False              False              False
# 2                   False              False              False
# 3                   False              False              False
# 4                   False              False              False
# ...                   ...                ...                ...
# 291527              False              False              False
# 291528              False              False              False
# 291529              False              False              False
# 291530              False              False              False
# 291531              False              False              False
#
#         Encoded_994.0 / 4  Encoded_996.0 / 4  Encoded_997.0 / 4  \
# 0                   False              False              False
# 1                   False              False              False
# 2                   False              False              False
# 3                   False              False              False
# 4                   False              False              False
# ...                   ...                ...                ...
# 291527              False              False              False
# 291528              False              False              False
# 291529              False              False              False
# 291530              False              False              False
# 291531              False              False              False
#
#         Encoded_998.0 / 4  Encoded_999.0 / 4
# 0                   False              False
# 1                   False              False
# 2                   False              False
# 3                   False              False
# 4                   False              False
# ...                   ...                ...
# 291527              False              False
# 291528              False              False
# 291529              False              False
# 291530              False              False
# 291531              False              False
#
# [291532 rows x 8139 columns]

# %%
df_ohe.dtypes
# Out:
# Encoded_0600-0659    bool
# Encoded_0700-0759    bool
# Encoded_0800-0859    bool
# Encoded_0900-0959    bool
# Encoded_1000-1059    bool
#                      ...
# Encoded_994.0 / 4    bool
# Encoded_996.0 / 4    bool
# Encoded_997.0 / 4    bool
# Encoded_998.0 / 4    bool
# Encoded_999.0 / 4    bool
# Length: 8139, dtype: object

# %%
df_ohe.shape
# Out:
# (291532, 8139)

# %% [markdown]
# Veri fazla büyük, fazla sınıfa sahip kategorik değişkenleri çıkaralım.

# %%
df.select_dtypes(object).nunique()
# Out:
# DepTimeBlk                               13
# Merged by Marketing_Airline_Network    3996
# Merged by Operating_Airline              14
# Merged by OriginAirportID               318
# Merged by DestAirportSeqID              317
# Merged by DepDelay                      739
# Merged by CRSArrTime                    660
# Merged by ArrDelay                      786
# Merged by Distance                     1296
# DelayLabel                                3
# dtype: int64

# %% [markdown]
# Merged by Marketing_Airline_Network özniteliği veriyi oldukça büyütüyor. Onu ayıklayalım.

# %%
df_objects_ = df.select_dtypes(include=[object]).iloc[:, [0]+list(range(2,df.select_dtypes(object).shape[1]-1))]

# %%
df_ohe = pd.get_dummies(df_objects_, prefix='Encoded')

memory_usage = df_ohe.memory_usage(deep=True)

# Toplam bellek kullanımını MB cinsinden görüntüle
total_memory_mb = memory_usage.sum() / (1024 ** 2)
print(f"\nToplam Bellek Kullanımı: {total_memory_mb:.2f} MB")

# Toplam bellek kullanımını GB cinsinden görüntüle
total_memory_gb = memory_usage.sum() / (1024 ** 3)
print(f"Toplam Bellek Kullanımı: {total_memory_gb:.4f} GB")
# Out:
# Toplam Bellek Kullanımı: 1151.86 MB
# Toplam Bellek Kullanımı: 1.1249 GB

# %%
df_ohe_ = df_ohe.astype(int)

memory_usage = df_ohe_.memory_usage(deep=True)

# Toplam bellek kullanımını MB cinsinden görüntüle
total_memory_mb = memory_usage.sum() / (1024 ** 2)
print(f"\nToplam Bellek Kullanımı: {total_memory_mb:.2f} MB")

# Toplam bellek kullanımını GB cinsinden görüntüle
total_memory_gb = memory_usage.sum() / (1024 ** 3)
print(f"Toplam Bellek Kullanımı: {total_memory_gb:.4f} GB")
# Out:
# Toplam Bellek Kullanımı: 4607.46 MB
# Toplam Bellek Kullanımı: 4.4995 GB

# %%
array_encoded_scaled = np.concatenate([df_ohe.values, numeric_atts_scaled], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 array_encoded_scaled = np.concatenate([df_ohe.values, numeric_atts_scaled], axis = 1)
#
# MemoryError: Unable to allocate 9.03 GiB for an array with shape (291532, 4156) and data type float64

# %%
array_encoded_scaled.shape
# Out:
# (291532, 4156)

# %%
array_encoded_scaled.shape[0]/2
# Out:
# 145766.0

# %%
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans
import warnings

kmeans = KMeans()
visualizer = KElbowVisualizer(kmeans, k=(1,8))

#ignore warnings
warnings.filterwarnings("ignore", category=FutureWarning)

visualizer.fit(array_encoded_scaled[:int(array_encoded_scaled.shape[0]/50), :])
visualizer.poof()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# Etiketli verilerimizi üç grupta sınıflandırmıştık. K-means ile de öyle görünmektedir ki, gözetimsiz olarak da veri seti üç sınıfta kümelenebilmektedir. (En optimal k değeri 3 görünmektedir.) Peki gözetimsiz olarak ayrışan bu 3 grup, etiketli sınıflandırma verilerimiz ile ne kadar tutarlı?

# %%
# KMeans modeli oluştur
simple_array_encoded_scaled = array_encoded_scaled[:int(array_encoded_scaled.shape[0]/50), :]

kmeans = KMeans(n_clusters=3)
kmeans.fit(simple_array_encoded_scaled)

# Her bir gözlemin hangi kümeleme kümesine ait olduğunu görüntüle
unsupervised_labels = kmeans.labels_

# %%
unsupervised_labels[:10]
# Out:
# array([2, 1, 1, 2, 1, 0, 2, 2, 1, 2])

# %%
supervised_labels = df.DelayLabel

# %%
pd.Series(supervised_labels)
# Out:
# 0         Almost on time
# 1         Almost on time
# 2         Almost on time
# 3                  Early
# 4         Almost on time
#                ...
# 291527             Delay
# 291528    Almost on time
# 291529             Delay
# 291530    Almost on time
# 291531             Delay
# Name: DelayLabel, Length: 291532, dtype: object

# %%
supervised_labels.shape
# Out:
# (291532,)

# %%
len_labels = int(supervised_labels.shape[0]/50)

# %%
supervised_labels.iloc[:len_labels].shape
# Out:
# (5830,)

# %%
unsupervised_labels = pd.Series(unsupervised_labels)

# %%
df_comparation = pd.concat([supervised_labels.iloc[:len_labels], unsupervised_labels], axis=1)

# %%
df_comparation
# Out:
#           DelayLabel  0
# 0     Almost on time  2
# 1     Almost on time  1
# 2     Almost on time  1
# 3              Early  2
# 4     Almost on time  1
# ...              ... ..
# 5825  Almost on time  1
# 5826  Almost on time  0
# 5827  Almost on time  2
# 5828  Almost on time  1
# 5829  Almost on time  2
#
# [5830 rows x 2 columns]

# %%
df_comparation.value_counts()
# Out:
# DelayLabel      0
# Almost on time  2    1319
#                 1    1242
#                 0     758
# Delay           2     722
#                 1     465
# Early           1     449
# Delay           0     356
# Early           2     353
#                 0     166
# Name: count, dtype: int64

# %% [markdown]
# Gözetimsiz etiketler ile gözetimli sınıflarımız çok da örtüşüyor gibi görünmüyor.

# %%
numeric_atts_df_scaled
# Out:
#         Flight_Number_Marketing_Airline  CRSDepTime   DepTime   TaxiOut  \
# 0                             -0.817258    1.278581  1.190874 -0.241404
# 1                             -0.816695   -0.567731 -0.602018 -0.046715
# 2                             -0.816133   -0.284853 -0.324827 -0.338748
# 3                             -0.816133    0.080151  0.020187 -0.630781
# 4                             -0.815570   -0.944901 -1.079729 -0.436092
# ...                                 ...         ...       ...       ...
# 291527                         1.666006    1.248164 -0.032892  1.413449
# 291528                         1.666006    1.248164  1.184977 -0.728125
# 291529                         1.666006    1.248164  1.529990 -0.436092
# 291530                         1.666568    1.610126  1.518195  0.634695
# 291531                         1.666568    1.610126  1.833720  0.050629
#
#           TaxiIn   ArrTime  Cancelled  Diverted  CRSElapsedTime  \
# 0      -0.416642  1.185754        0.0       0.0       -0.417425
# 1      -0.702176 -0.682987        0.0       0.0       -0.209648
# 2      -0.559409 -0.931948        0.0       0.0       -0.816996
# 3      -0.416642  0.002423        0.0       0.0       -0.880928
# 4       0.011658 -1.217791        0.0       0.0       -0.417425
# ...          ...       ...        ...       ...             ...
# 291527  5.151264  0.211427        0.0       0.0        0.237872
# 291528  1.153793  1.213416        0.0       0.0        0.237872
# 291529  3.295295  1.751294        0.0       0.0        0.237872
# 291530 -0.702176  1.468524        0.0       0.0       -0.657168
# 291531 -0.273876  1.800471        0.0       0.0       -0.657168
#
#         ActualElapsedTime   AirTime  Flights  DivAirportLandings
# 0               -0.250867 -0.167621      0.0           -0.001852
# 1               -0.250867 -0.167621      0.0           -0.001852
# 2               -0.815845 -0.712981      0.0           -0.001852
# 3               -1.025694 -0.894768      0.0           -0.001852
# 4               -0.444574 -0.382460      0.0           -0.001852
# ...                   ...       ...      ...                 ...
# 291527           0.685382 -0.134569      0.0           -0.001852
# 291528          -0.073303 -0.084990      0.0           -0.001852
# 291529           0.217257 -0.084990      0.0           -0.001852
# 291530          -0.557569 -0.597298      0.0           -0.001852
# 291531          -0.541427 -0.531194      0.0           -0.001852
#
# [291532 rows x 13 columns]

# %%
numeric_atts.to_csv(r'G:\Other computers\My Laptop D14\Belgeler\CODING\Python.PROJECTS\MTM-DataMining-FlightDelay\manipulated_data\flightDelay_numeric_atts.csv', index=False)

numeric_atts_df_scaled.to_csv(r'G:\Other computers\My Laptop D14\Belgeler\CODING\Python.PROJECTS\MTM-DataMining-FlightDelay\manipulated_data\flightDelay_numeric_atts_scaled.csv', index=False)

df_objects_.to_csv(r'G:\Other computers\My Laptop D14\Belgeler\CODING\Python.PROJECTS\MTM-DataMining-FlightDelay\manipulated_data\flightDelay_objects.csv', index=False)

df_ohe.to_csv(r'G:\Other computers\My Laptop D14\Belgeler\CODING\Python.PROJECTS\MTM-DataMining-FlightDelay\manipulated_data\flightDelay_objects_encoded.csv', index=False)

df.iloc[:, [-1, -5]].to_csv(r'G:\Other computers\My Laptop D14\Belgeler\CODING\Python.PROJECTS\MTM-DataMining-FlightDelay\manipulated_data\flightDelay_targets.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 7
#       3 numeric_atts_df_scaled.to_csv(r'G:\Other computers\My Laptop D14\Belgeler\CODING\Python.PROJECTS\MTM-DataMining-FlightDelay\manipulated_data\flightDelay_numeric_atts_scaled.csv', index=False)
#       5 df_objects_.to_csv(r'G:\Other computers\My Laptop D14\Belgeler\CODING\Python.PROJECTS\MTM-DataMining-FlightDelay\manipulated_data\flightDelay_objects.csv', index=False)
# ----> 7 df_ohe.to_csv(r'G:\Other computers\My Laptop D14\Belgeler\CODING\Python.PROJECTS\MTM-DataMining-FlightDelay\manipulated_data\flightDelay_objects_encoded.csv', index=False)
#       9 df.iloc[:, [-1, -5]].to_csv(r'G:\Other computers\My Laptop D14\Belgeler\CODING\Python.PROJECTS\MTM-DataMining-FlightDelay\manipulated_data\flightDelay_targets.csv', index=False)
#
# File c:\Users\Anıl\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:3902, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3891 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3893 formatter = DataFrameFormatter(
#    3894     frame=df,
#    3895     header=header,
#    (...)
#    3899     decimal=decimal,
#    3900 )
# -> 3902 return DataFrameRenderer(formatter).to_csv(
#    3903     path_or_buf,
#    3904     lineterminator=lineterminator,
#    3905     sep=sep,
#    3906     encoding=encoding,
#    3907     errors=errors,
#    3908     compression=compression,
#    3909     quoting=quoting,
#    3910     columns=columns,
#    3911     index_label=index_label,
#    3912     mode=mode,
#    3913     chunksize=chunksize,
#    3914     quotechar=quotechar,
#    3915     date_format=date_format,
#    3916     doublequote=doublequote,
#    3917     escapechar=escapechar,
#    3918     storage_options=storage_options,
#    3919 )
#
# File c:\Users\Anıl\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\format.py:1152, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1131     created_buffer = False
#    1133 csv_formatter = CSVFormatter(
#    1134     path_or_buf=path_or_buf,
#    1135     lineterminator=lineterminator,
#    (...)
#    1150     formatter=self.fmt,
#    1151 )
# -> 1152 csv_formatter.save()
#    1154 if created_buffer:
#    1155     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\Anıl\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\csvs.py:266, in CSVFormatter.save(self)
#     247 with get_handle(
#     248     self.filepath_or_buffer,
#     249     self.mode,
#    (...)
#     254 ) as handles:
#     255     # Note: self.encoding is irrelevant here
#     256     self.writer = csvlib.writer(
#     257         handles.handle,
#     258         lineterminator=self.lineterminator,
#    (...)
#     263         quotechar=self.quotechar,
#     264     )
# --> 266     self._save()
#
# File c:\Users\Anıl\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\csvs.py:271, in CSVFormatter._save(self)
#     269 if self._need_to_save_header:
#     270     self._save_header()
# --> 271 self._save_body()
#
# File c:\Users\Anıl\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\csvs.py:309, in CSVFormatter._save_body(self)
#     307 if start_i >= end_i:
#     308     break
# --> 309 self._save_chunk(start_i, end_i)
#
# File c:\Users\Anıl\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\formats\csvs.py:320, in CSVFormatter._save_chunk(self, start_i, end_i)
#     317 data = [res.iget_values(i) for i in range(len(res.items))]
#     319 ix = self.data_index[slicer]._format_native_types(**self._number_format)
# --> 320 libwriters.write_csv_rows(
#     321     data,
#     322     ix,
#     323     self.nlevels,
#     324     self.cols,
#     325     self.writer,
#     326 )
#
# File writers.pyx:75, in pandas._libs.writers.write_csv_rows()
#
# KeyboardInterrupt:

# %%
df_objects_
# Out:
#        DepTimeBlk Merged by Operating_Airline  \
# 0       1600-1659             DL / 19790 / DL
# 1       1000-1059             DL / 19790 / DL
# 2       1100-1159             DL / 19790 / DL
# 3       1200-1259             DL / 19790 / DL
# 4       0900-0959             DL / 19790 / DL
# ...           ...                         ...
# 291527  1600-1659             YV / 20378 / YV
# 291528  1600-1659             YV / 20378 / YV
# 291529  1600-1659             YV / 20378 / YV
# 291530  1700-1759             YV / 20378 / YV
# 291531  1700-1759             YV / 20378 / YV
#
#                                 Merged by OriginAirportID  \
# 0       10397 / 1039707 / 30397 / ATL / Atlanta, GA / ...
# 1       11697 / 1169706 / 32467 / FLL / Fort Lauderdal...
# 2       10397 / 1039707 / 30397 / ATL / Atlanta, GA / ...
# 3       12448 / 1244807 / 32448 / JAN / Jackson/Vicksb...
# 4       14524 / 1452401 / 34524 / RIC / Richmond, VA /...
# ...                                                   ...
# 291527  11003 / 1100303 / 31003 / CID / Cedar Rapids/I...
# 291528  11003 / 1100303 / 31003 / CID / Cedar Rapids/I...
# 291529  11003 / 1100303 / 31003 / CID / Cedar Rapids/I...
# 291530  11298 / 1129806 / 30194 / DFW / Dallas/Fort Wo...
# 291531  11298 / 1129806 / 30194 / DFW / Dallas/Fort Wo...
#
#                                Merged by DestAirportSeqID  \
# 0       1169706 / 11697 / 32467 / FLL / Fort Lauderdal...
# 1       1449202 / 14492 / 34492 / RDU / Raleigh/Durham...
# 2       1244807 / 12448 / 32448 / JAN / Jackson/Vicksb...
# 3       1039707 / 10397 / 30397 / ATL / Atlanta, GA / ...
# 4       1039707 / 10397 / 30397 / ATL / Atlanta, GA / ...
# ...                                                   ...
# 291527  1129806 / 11298 / 30194 / DFW / Dallas/Fort Wo...
# 291528  1129806 / 11298 / 30194 / DFW / Dallas/Fort Wo...
# 291529  1129806 / 11298 / 30194 / DFW / Dallas/Fort Wo...
# 291530  1342202 / 13422 / 30562 / MOB / Mobile, AL / A...
# 291531  1342202 / 13422 / 30562 / MOB / Mobile, AL / A...
#
#                   Merged by DepDelay Merged by CRSArrTime  \
# 0            -4.0 / 0.0 / 0.0 / -1.0     1821 / 1800-1859
# 1            -5.0 / 0.0 / 0.0 / -1.0     1227 / 1200-1259
# 2            -4.0 / 0.0 / 0.0 / -1.0     1142 / 1100-1159
# 3            -7.0 / 0.0 / 0.0 / -1.0     1458 / 1400-1459
# 4            -3.0 / 0.0 / 0.0 / -1.0     1050 / 1000-1059
# ...                              ...                  ...
# 291527  1191.0 / 1191.0 / 1.0 / 12.0     1852 / 1800-1859
# 291528         4.0 / 4.0 / 0.0 / 0.0     1852 / 1800-1859
# 291529       81.0 / 81.0 / 1.0 / 5.0     1852 / 1800-1859
# 291530       -2.0 / 0.0 / 0.0 / -1.0     1915 / 1900-1959
# 291531       65.0 / 65.0 / 1.0 / 4.0     1915 / 1900-1959
#
#                   Merged by ArrDelay Merged by Distance
# 0            -1.0 / 0.0 / 0.0 / -1.0          581.0 / 3
# 1           -15.0 / 0.0 / 0.0 / -1.0          680.0 / 3
# 2           -11.0 / 0.0 / 0.0 / -1.0          341.0 / 2
# 3           -23.0 / 0.0 / 0.0 / -2.0          341.0 / 2
# 4           -12.0 / 0.0 / 0.0 / -1.0          481.0 / 2
# ...                              ...                ...
# 291527  1211.0 / 1211.0 / 1.0 / 12.0          685.0 / 3
# 291528      -23.0 / 0.0 / 0.0 / -2.0          685.0 / 3
# 291529       72.0 / 72.0 / 1.0 / 4.0          685.0 / 3
# 291530       -3.0 / 0.0 / 0.0 / -1.0          539.0 / 3
# 291531       65.0 / 65.0 / 1.0 / 4.0          539.0 / 3
#
# [291532 rows x 8 columns]
